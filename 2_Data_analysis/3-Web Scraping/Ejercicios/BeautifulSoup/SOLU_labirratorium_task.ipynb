# %% [markdown]
# ###  Pasos a seguir en el proceso de 'scraping':
#
# 1. Encuentra la URL que quieres 'escrapear'.
# 2. Inspecciona la página (código fuente).
# 3. Localiza los datos que necesitas obtener.
# 4. Desarrolla tu código en Python.
#     1. Crea tu sopa
#     2. Busca los elementos que cotienen los datos y extráelos
# 5. Ejecuta tu código y obten los datos.
# 6. Alamacena los datos en el formato requerido.

# %%
# Importamos librerías
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import html
import numpy as np

# %% [markdown]
# ## Caso 1: Scraping de un catálogo: Labirratorium

# %%
URL = 'https://www.labirratorium.com/es/67-cervezas-por-estilo?page='

# %% [markdown]
# Queremos obtener un dataFrame con todas las cervezas del catálogo y sus características descritas. Analizamos la página para ver qué tenemos que hacer para conseguirlo

# %%
# La web tiene 80 páginas con 12 cervezas listadas en cada página.

# %% [markdown]
# Hacemos la consulta (request) y creamos la SOPA inicial:

# %%
r = requests.get(URL)
soup = bs(r.text, 'lxml')

# %%
# Guardamos lista de cervezas
cervezas_grid = soup.find_all(class_='product-image')
cervezas_grid[0]
# Out:
# <div class="product-image">
# <!-- @file modules\appagebuilder\views\templates\front\products\file_tpl -->
# <ul class="product-flags">
# </ul>
# <a class="thumbnail product-thumbnail" href="https://www.labirratorium.com/es/inicio/831--vikingathor-.html">
# <img alt="" class="img-fluid" data-full-size-image-url="https://www.labirratorium.com/27941-large_default/-vikingathor-.jpg" src="https://www.labirratorium.com/27941-home_default/-vikingathor-.jpg"/>
# <span class="product-additional" data-idproduct="831"></span>
# </a>
# </div>

# %%
# necesitamos acceder a cada una de las cervezas del grid:
lista_URLs = []
for cerveza in cervezas_grid:
    URL_cerveza = cerveza.find('a')['href']
    lista_URLs.append(URL_cerveza)

lista_URLs
# Out:
# ['https://www.labirratorium.com/es/inicio/831--vikingathor-.html',
#  'https://www.labirratorium.com/es/inicio/479-la-vermontoise-75cl-hill-farmsteadblaugies.html',
#  'https://www.labirratorium.com/es/botella-33cl/199-orval.html',
#  'https://www.labirratorium.com/es/inicio/183-schneider-eisbock.html',
#  'https://www.labirratorium.com/es/inicio/181-schlenkerla-rauchbier-weizen.html',
#  'https://www.labirratorium.com/es/inicio/173-samuel-adams-boston-lager.html',
#  'https://www.labirratorium.com/es/inicio/82-westmalle-dubbel.html',
#  'https://www.labirratorium.com/es/sin-alcohol/29-bavaria-wit-00.html',
#  'https://www.labirratorium.com/es/inicio/182-weihenstephaner-korbinian.html',
#  'https://www.labirratorium.com/es/inicio/83-westmalle-tripel.html',
#  'https://www.labirratorium.com/es/inicio/44-chimay-azul-grande-reserve.html',
#  'https://www.labirratorium.com/es/inicio/13-achel-brune.html']

# %%
# Hacemos un nuevo request para la primera cerveza: 
r = requests.get(lista_URLs[0])

# Creamos una sopa específica con la info de cada cerveza
soup_cerveza = bs(r.text, 'lxml')

# %%
# Nombre
name = soup_cerveza.find(class_='h1 product-detail-name')
name
# Out:
# <h1 class="h1 product-detail-name" itemprop="name">SanFrutos Vikingathor Boris Brew</h1>

# %%
# Precio
price = float(soup_cerveza.find(class_='current-price').find('span')['content'])
price
# Out:
# 3.35

# %%
# Descripcion corta
descr_short = soup_cerveza.find(class_='description-short').find('p').text
descr_short
# Out:
# 'Indian Dunkel'

# %%
# Descripción larga
descr_full_list = []

descr_full_p = soup_cerveza.find(class_='product-description').find_all()
for sentence in descr_full_p:
    descr_full_list.append(sentence.text)

descr_full = '\n'.join(descr_full_list)

print(descr_full)
# Out:
# Cerveza de 8.2% ABV intensa, oscura y muy lupulada. Con aroma intenso a maltas tostadas, caramelo, fruta madura, resina e hierbas aromáticas. Delicioso armargor, dulzor equilibrado y sensación de calidez. Refrescante y lupulada.
# Una receta de Boris de Mesones.
# Vikingathor ya ha sido galardonada con anterioridad con las Medallas de Plata cosechadas en el European Beer Star de 2011 y 2012 y la Medalla de Plata en el Asia Beer Cup 2013.
# Medallas de Plata
# European Beer Star
# Medalla de Plata
# Asia Beer Cup

# %%
# Imagen
image = soup_cerveza.find(class_='js-qv-product-cover img-fluid')['src']
image
# Out:
# 'https://www.labirratorium.com/27941-large_default/-vikingathor-.jpg'

# %%
 # Brand
 brand = soup_cerveza.find(class_='img img-thumbnail manufacturer-logo')['alt']
 brand
# Out:
# 'Cerveza Sanfrutos'

# %%
# Código de barras
try:
    barcode = soup_cerveza.find(class_='product-reference').find('span').text
except:
    barcode = None
print(barcode)
# Out:
# 831

# %%
# Features
features_dict = {}

try:
    features_dt = soup_cerveza.find_all('dt')
    features_dd = soup_cerveza.find_all('dd')
    for feature, value in zip(features_dt, features_dd):
        features_dict[feature.text] = value.text
except:
    features_dict = {}

features_dict
# Out:
# {'Estilo': 'DUNKEL',
#  'Origen': 'Segovia',
#  '% Alc.': 'ALTO (6-9%)',
#  '% Alc. Exacto': '8.2',
#  'Volumen (cl)': '33 Cl',
#  'Tipo Fermentación': 'Lager (Baja Fermentación)',
#  'IBU': '50-75 Amargor alto',
#  'IBU Exacto': '75',
#  'Color': 'Marrón',
#  'Envase': 'Botella'}

# %%
# Creamos un Id único que os permita diferenciar cada entrada en la BBDD
counter = 1
id_cerv = 'lbt_' + str(counter)

id_cerv
# Out:
# 'lbt_1'

# %% [markdown]
# Ya tenemos todos los datos que queremos de la cerveza: Agrupamos todo en una lista:

# %%
# Agregamos a una lista
lista_cervezas = []

lista_cervezas.append([
    ("id", id_cerv),
    ("name", name),
    ('price', price),
    ('descr_short', descr_short),
    ('descr_full', descr_full),
    ('image', image),
    ('brand', brand),
    ('barcode', barcode),
    ('features', features_dict)
])

lista_cervezas
# Out:
# [[('id', 'lbt_1'),
#   ('name',
#    <h1 class="h1 product-detail-name" itemprop="name">SanFrutos Vikingathor Boris Brew</h1>),
#   ('price', 3.35),
#   ('descr_short', 'Indian Dunkel'),
#   ('descr_full',
#    'Cerveza de 8.2% ABV intensa, oscura y muy lupulada. Con aroma intenso a maltas tostadas, caramelo, fruta madura, resina e hierbas aromáticas. Delicioso armargor, dulzor equilibrado y sensación de calidez. Refrescante y lupulada.\xa0\nUna receta de Boris de Mesones.\nVikingathor ya ha sido galardonada con anterioridad con las\xa0Medallas de Plata\xa0cosechadas en el\xa0European Beer Star\xa0de 2011 y 2012 y la\xa0Medalla de Plata\xa0en el\xa0Asia Beer Cup\xa02013.\nMedallas de Plata\nEuropean Beer Star\nMedalla de Plata\nAsia Beer Cup\n\n'),
#   ('image',
#    'https://www.labirratorium.com/27941-large_default/-vikingathor-.jpg'),
#   ('brand', 'Cerveza Sanfrutos'),
#   ('barcode', '831'),
#   ('features',
#    {'Estilo': 'DUNKEL',
#     'Origen': 'Segovia',
#     '% Alc.': 'ALTO (6-9%)',
#     '% Alc. Exacto': '8.2',
#     'Volumen (cl)': '33 Cl',
#     'Tipo Fermentación': 'Lager (Baja Fermentación)',
#     'IBU': '50-75 Amargor alto',
#     'IBU Exacto': '75',
#     'Color': 'Marrón',
#     'Envase': 'Botella'})]]

# %% [markdown]
# ### Ya sabemos obtener todos los datos que nos interesan de una cerveza, ahora tenemos que aplicar esta lógica para obtener todas las demás

# %% [markdown]
# Construir un DataFrame

# %%
pages = np.arange(1,5)
count = 1
lista_cervezas = []

for page in pages:
    URL = 'https://www.labirratorium.com/es/67-cervezas-por-estilo?page=' + str(page)
    r = requests.get(URL)
    soup = bs(r.text, 'lxml')
    cervezas_grid = soup.find_all(class_='product-image')
    count_beer = 1

    for cerveza in cervezas_grid:
        print('Cerveza {} de {}, pag {}/{}'.format(count_beer, len(cervezas_grid), page, len(pages)))

        URL_cerveza = cerveza.find('a')['href']
        r = requests.get(URL_cerveza)
        soup_cerveza = bs(r.text, 'lxml')

        name = soup_cerveza.find(class_='h1 product-detail-name').text   

        price = soup_cerveza.find(class_='current-price').find('span')['content']

        try:
            descr_short = soup_cerveza.find(class_='description-short').find('p').text
        except:
            descr_short = None

        descr_full_list = []
        descr_full_p = soup_cerveza.find(class_='product-description').find_all('p')
        for sentence in descr_full_p:
            descr_full_list.append(sentence.text)
            
        descr_full = "\n".join(descr_full_list)

        image = soup_cerveza.find(class_='js-qv-product-cover img-fluid')['src']

        try:
            brand = soup_cerveza.find(class_='img img-thumbnail manufacturer-logo')['alt']
        except:
            brand = None

        try:
            barcode = soup_cerveza.find(class_='product-reference').find('span').text
        except:
            barcode = None
        
        features_dicc = {}
        features = soup_cerveza.find(class_ = 'data-sheet')
        
        try:
            features_dt = features.find_all('dt')
            features_dd = features.find_all('dd')
            for feature, value in zip(features_dt, features_dd):
                #print(feature.text, value.text)
                features_dicc[feature.text] = value.text
        except:
            features_dicc = {}

        data = {"id_libro": count_beer,
                "name": name,
                "price": price,
                "descr_short": descr_short,
                "descr_full": descr_full,
                "brand": brand,
                "barcode": barcode,
                "image": image,
                'features': features_dicc}

        lista_cervezas.append(data)
        count_beer += 1
        count = +1
# Out:
# Cerveza 1 de 12, pag 1/4
# Cerveza 2 de 12, pag 1/4
# Cerveza 3 de 12, pag 1/4
# Cerveza 4 de 12, pag 1/4
# Cerveza 5 de 12, pag 1/4
# Cerveza 6 de 12, pag 1/4
# Cerveza 7 de 12, pag 1/4
# Cerveza 8 de 12, pag 1/4
# Cerveza 9 de 12, pag 1/4
# Cerveza 10 de 12, pag 1/4
# Cerveza 11 de 12, pag 1/4
# Cerveza 12 de 12, pag 1/4
# Cerveza 1 de 12, pag 2/4
# Cerveza 2 de 12, pag 2/4
# Cerveza 3 de 12, pag 2/4
# Cerveza 4 de 12, pag 2/4
# Cerveza 5 de 12, pag 2/4
# Cerveza 6 de 12, pag 2/4
# Cerveza 7 de 12, pag 2/4
# Cerveza 8 de 12, pag 2/4
# Cerveza 9 de 12, pag 2/4
# Cerveza 10 de 12, pag 2/4
# Cerveza 11 de 12, pag 2/4
# Cerveza 12 de 12, pag 2/4
# Cerveza 1 de 12, pag 3/4
# Cerveza 2 de 12, pag 3/4
# Cerveza 3 de 12, pag 3/4
# Cerveza 4 de 12, pag 3/4
# Cerveza 5 de 12, pag 3/4
# Cerveza 6 de 12, pag 3/4
# Cerveza 7 de 12, pag 3/4
# Cerveza 8 de 12, pag 3/4
# Cerveza 9 de 12, pag 3/4
# Cerveza 10 de 12, pag 3/4
# Cerveza 11 de 12, pag 3/4
# Cerveza 12 de 12, pag 3/4
# Cerveza 1 de 12, pag 4/4
# Cerveza 2 de 12, pag 4/4
# Cerveza 3 de 12, pag 4/4
# Cerveza 4 de 12, pag 4/4
# Cerveza 5 de 12, pag 4/4
# Cerveza 6 de 12, pag 4/4
# Cerveza 7 de 12, pag 4/4
# Cerveza 8 de 12, pag 4/4
# Cerveza 9 de 12, pag 4/4
# Cerveza 10 de 12, pag 4/4
# Cerveza 11 de 12, pag 4/4
# Cerveza 12 de 12, pag 4/4

# %%
df = pd.DataFrame(lista_cervezas)
df
# Out:
#     id_libro                                               name  price  \
# 0          1                   SanFrutos Vikingathor Boris Brew   3.35
# 1          2  Blaugies / Hill Farmstead La Vermontoise 37,5 cl.    6.6
# 2          3                                              Orval   3.15
# 3          4                 Schneider Aventinus Weizen-Eisbock      3
# 4          5                 Aecht Schlenkerla Rauchbier Weizen   2.85
# 5          6                          Samuel Adams Boston Lager   2.45
# 6          7                                   Westmalle Dubbel   2.18
# 7          8                                   Bavaria Wit 0.0%   2.15
# 8          9                          Weihenstephaner Korbinian   3.35
# 9         10                                   Westmalle Tripel      3
# 10        11                    Chimay Azul Grande Réserve 75cl   8.55
# 11        12                                        Achel Brune   2.95
# 12         1             Aecht Schlenkerla Rauchbier Doppelbock    3.5
# 13         2                             Lindemans Kriek 25 cl.    2.7
# 14         3                             Straffe Hendrik Tripel   3.65
# 15         4                                       Achel Blonde    3.1
# 16         5                 Aecht Schlenkerla Rauchbier Urbock   2.95
# 17         6                                   Brewdog Punk IPA   3.05
# 18         7                                  DouGall's Raquera    2.3
# 19         8                             Trappistes Rochefort 8   3.25
# 20         9                              Tripel Karmeliet 75cl   7.35
# 21        10                               St. Bernardus Abt 12    3.4
# 22        11          Oud Beersel Bersalis Tripel Oak Aged 2017    6.5
# 23        12                                      Caleya Goma 2      3
# 24         1            Les Trois Mousquetaires Porter Baltique  12.95
# 25         2                                       Gulden Draak   2.95
# 26         3                          Straffe Hendrik Quadrupel    3.6
# 27         4                          Schneider Tap 6 Aventinus   2.55
# 28         5                      Hanssens Oude Gueuze 37,5 cl.      6
# 29         6                              Blanche de Namur 75cl   5.55
# 30         7                            Trappistes Rochefort 10    4.4
# 31         8                                      Saison Dupont    2.2
# 32         9                    Brunehaut Tripel Bio Sin Gluten   3.95
# 33        10                                  Gulden Draak 9000   2.95
# 34        11                                     Laugar Kiskale   3.15
# 35        12                              La Quince Hop Fiction   2.95
# 36         1                        Cantillon Oude Kriek 37.5cl   15.2
# 37         2                                  La Chouffe 75 cl.    6.5
# 38         3                              Mikkeller Energibajer    2.9
# 39         4                                 Samichlaus Classic      5
# 40         5                                La Trappe Quadrupel    3.2
# 41         6                                  St. Bernardus Wit   2.45
# 42         7             Wychwood Hobgoblin Legendary Ruby Beer   3.75
# 43         8                          Hacker Pschorr Kellerbier    2.6
# 44         9                                    Ayinger Maibock   3.15
# 45        10                                      Chimay Blanca    2.8
# 46        11                                         Kozel Dark   2.35
# 47        12                                  Anchor Steam Beer   3.15
#
#                                           descr_short  \
# 0                                       Indian Dunkel
# 1                                              Saison
# 2                                    Belgian Pale Ale
# 3   Cerveza de color medio oscuro, aromas alcohóli...
# 4
# 5   Cerveza de baja fermentación (Lager) de color ...
# 6                                              Dubbel
# 7   Cerveza holandesa de trigo sin alcohol, de col...
# 8                                          Doppelbock
# 9                                              Tripel
# 10                                 Belgian Strong Ale
# 11                                     Belgian Dubbel
# 12                             Rauchbier / Doppelbock
# 13                                     Lambic / Kriek
# 14              Cerveza rubia estilo Tripel de abadía
# 15                          Belgian Strong Golden Ale
# 16                                  Rauchbier / Lager
# 17                                     India Pale Ale
# 18                                             Pilsen
# 19                            Belgian Strong Dark Ale
# 20                                             Tripel
# 21                                          Quadrupel
# 22                                    Sour / Wild Ale
# 23                                                IPA
# 24                                      Baltic Porter
# 25                            Belgian Strong Dark Ale
# 26                                          Quadrupel
# 27                                   Weizendoppelbock
# 28                                    Lambic / Gueuze
# 29                                            Witbier
# 30                            Belgian Strong Dark Ale
# 31                             Saison / Farmhouse Ale
# 32                       Sin Gluten / Belgian Triple
# 33                                          Quadrupel
# 34                                          Brown Ale
# 35                                  American Pale Ale
# 36                                     Lambic / Kriek
# 37                               Belgian Strong Ale.
# 38                       Cerveza Sin Alcohol de trigo
# 39                                         Doppelbock
# 40                                  Belgian Quadrupel
# 41                                            Witbier
# 42                                 English Brown Ale
# 43                                         Kellerbier
# 44                              Maibock / Helles Bock
# 45                                     Belgian Tripel
# 46                                         Dark Lager
# 47                                  California Common
#
#                                            descr_full  \
# 0   Cerveza de 8.2% ABV intensa, oscura y muy lupu...
# 1   Saison de 6% ABV elaborada con lúpulo Amarillo...
# 2   Orval es una cerveza tipo ale y es la que prin...
# 3   Cerveza de color medio oscuro, aromas alcohóli...
# 4   Rauchbier (cerveza ahumada) de trigo con 5.2% ...
# 5   Apariencia: color ambarino cobrizo y espuma pe...
# 6   Cerveza Trapista belga con 7% ABV de color mar...
# 7   Cerveza holandesa sin alcohol, de color amaril...
# 8   Cerveza alemanda de estilo Doppelbock de 7.4% ...
# 9   Cerveza Trapista belga con 9% ABV de color oro...
# 10  Cerveza fuerte de abadía, de color oscuro, Afr...
# 11  Ale Trapense.De un color caoba muy bello y una...
# 12  Rauchbier (cerveza ahumada). Lager fuerte de 8...
# 13  Cerveza de fermentación espontánea (Lambic) de...
# 14  Cerveza de color amarillo dorado, con aromas e...
# 15  Densa, ligeramente amarga. Dulce y amarga a lú...
# 16  Rauchbier (cerveza ahumada). Lager fuerte de 6...
# 17  Cerveza Estilo IPA de 5.6% ABV elaborada en es...
# 18  Cerveza rubia ligera estilo Pilsen de 5% ABV\n...
# 19  Cerveza color marrón rojizo, aroma complejo af...
# 20  Cerveza de estilo Belgian Tripel con 8.4% ABV....
# 21  Cerveza belga fuerte elaborada al estilo del c...
# 22  Berslais Tripel aged 16 months in Chateauneuf ...
# 23  IPA de 6.3% ABV elaborada con lúpulos Citra y ...
# 24  Cerveza lager negra fuerte de 10% ABV, inspira...
# 25  Cerveza belga fuerte en la que se ha utilizado...
# 26  Cerveza de color marrón oscuro, aroma alcohóli...
# 27  Cerveza fuerte y oscura de trigo alemán de 8.2...
# 28  Hanssens Oude Gueuze es el resultado de mezcla...
# 29  Cerveza de trigo belga (estilo Witbier o Blanc...
# 30  Cerveza de color oscuro, con aromas a pasas, a...
# 31  Saison de 6.5% ABV. \nElaborada desde 1844 en ...
# 32  Cerveza sin gluten de estilo Belgian Triple de...
# 33  Cerveza belga de estilo Quadrupel extremadamen...
# 34  Brown Ale de 7.3% ABV elaborada con lúpulo Col...
# 35  Cerveza de estilo American Pale Ale de 5% ABV ...
# 36  Cerveza de fermentación espontánea (Lambic) si...
# 37  La Chouffe- Biere Blond. Cerveza rubia estilo ...
# 38  Cerveza Sin Alcohol 0% ABV con aroma a melocot...
# 39  Cerveza austriaca especial fuerte, de 14% ABV ...
# 40  Color: Cálido tono ámbar con una capa de espum...
# 41  St. Bernardus Wit, como su nombre indica es un...
# 42  Cerveza de 5.2% ABV de color ámbar rojizo, con...
# 43  Hacker-Pschorr Munchner Kellerbier es una cerv...
# 44  Cerveza Lager alemana de 6.9% ABV elaborada co...
# 45  Cerveza trapense de 8% ABV de estilo Tripel, C...
# 46  La mezcla de maltas tostadas y caramelizadas l...
# 47  Cerveza de color ámbar profundo y espuma blanc...
#
#                                                 brand barcode  \
# 0                                   Cerveza Sanfrutos     831
# 1                                            Blaugies     479
# 2                                               Orval     199
# 3                                           Schneider     183
# 4                                         Schlenkerla     181
# 5                                        Samuel Adams     173
# 6                                       Van Westmalle      82
# 7                                             Bavaria      29
# 8                                       Weihenstephan     182
# 9                                       Van Westmalle      83
# 10                                             Chimay      44
# 11  Brouwerij der Trappistenabdij De Achelse Kluis...      13
# 12                                        Schlenkerla     367
# 13                                          Lindemans     352
# 14                      De Halve Maan-Straffe Hendrik      69
# 15  Brouwerij der Trappistenabdij De Achelse Kluis...      12
# 16                                        Schlenkerla     671
# 17                                            Brewdog     211
# 18                                  Cerveza Dougall's     158
# 19                                          Rochefort      73
# 20                      Brouwerij Bosteels (AB InBev)      72
# 21                                     St. Bernardus       63
# 22                                        Oud Beersel    2466
# 23                                     Cerveza Caleya    2313
# 24                            Les Trois Mousquetaires     341
# 25                                     Van Steenberge      66
# 26                      De Halve Maan-Straffe Hendrik      68
# 27                                          Schneider      22
# 28                                           Hanssens    1305
# 29                                  Brasserie Du Bocq     208
# 30                                          Rochefort      74
# 31                                   Brasserie Dupont     930
# 32                                          Brunehaut     712
# 33                                     Van Steenberge     605
# 34                                             Laugar     589
# 35                                          La Quince     217
# 36                                          Cantillon    3725
# 37              Brasserie d'Achouffe (Duvel-Moortgat)      14
# 38                                          Mikkeller    4211
# 39                                  Schloss Eggenberg    1402
# 40                                          La Trappe     702
# 41                                     St. Bernardus      187
# 42                               Wychwood (Marston's)      97
# 43                                     Hacker-Pschorr    5209
# 44                                            Ayinger    3401
# 45                                             Chimay    1274
# 46                     Pivovar Velké Popovice (Asahi)    5130
# 47                   Anchor Brewing Company (Sapporo)     317
#
#                                                 image  \
# 0   https://www.labirratorium.com/27941-large_defa...
# 1   https://www.labirratorium.com/21794-large_defa...
# 2   https://www.labirratorium.com/385-large_defaul...
# 3   https://www.labirratorium.com/366-large_defaul...
# 4   https://www.labirratorium.com/364-large_defaul...
# 5   https://www.labirratorium.com/343-large_defaul...
# 6   https://www.labirratorium.com/102-large_defaul...
# 7   https://www.labirratorium.com/53-large_default...
# 8   https://www.labirratorium.com/365-large_defaul...
# 9   https://www.labirratorium.com/103-large_defaul...
# 10  https://www.labirratorium.com/67-large_default...
# 11  https://www.labirratorium.com/12481-large_defa...
# 12  https://www.labirratorium.com/777-large_defaul...
# 13  https://www.labirratorium.com/30322-large_defa...
# 14  https://www.labirratorium.com/89-large_default...
# 15  https://www.labirratorium.com/29924-large_defa...
# 16  https://www.labirratorium.com/1133-large_defau...
# 17  https://www.labirratorium.com/14452-large_defa...
# 18  https://www.labirratorium.com/9072-large_defau...
# 19  https://www.labirratorium.com/93-large_default...
# 20  https://www.labirratorium.com/92-large_default...
# 21  https://www.labirratorium.com/83-large_default...
# 22  https://www.labirratorium.com/34610-large_defa...
# 23  https://www.labirratorium.com/2759-large_defau...
# 24  https://www.labirratorium.com/30801-large_defa...
# 25  https://www.labirratorium.com/29959-large_defa...
# 26  https://www.labirratorium.com/88-large_default...
# 27  https://www.labirratorium.com/11199-large_defa...
# 28  https://www.labirratorium.com/2727-large_defau...
# 29  https://www.labirratorium.com/12375-large_defa...
# 30  https://www.labirratorium.com/94-large_default...
# 31  https://www.labirratorium.com/29511-large_defa...
# 32  https://www.labirratorium.com/1207-large_defau...
# 33  https://www.labirratorium.com/29961-large_defa...
# 34  https://www.labirratorium.com/30578-large_defa...
# 35  https://www.labirratorium.com/29288-large_defa...
# 36  https://www.labirratorium.com/4489-large_defau...
# 37  https://www.labirratorium.com/30264-large_defa...
# 38  https://www.labirratorium.com/12508-large_defa...
# 39  https://www.labirratorium.com/26711-large_defa...
# 40  https://www.labirratorium.com/1183-large_defau...
# 41  https://www.labirratorium.com/33601-large_defa...
# 42  https://www.labirratorium.com/119-large_defaul...
# 43  https://www.labirratorium.com/18088-large_defa...
# 44  https://www.labirratorium.com/6674-large_defau...
# 45  https://www.labirratorium.com/1784-large_defau...
# 46  https://www.labirratorium.com/6158-large_defau...
# 47  https://www.labirratorium.com/33362-large_defa...
#
#                                              features
# 0   {'Estilo': 'DUNKEL', 'Origen': 'Segovia', '% A...
# 1   {'Estilo': 'SAISON / FARMHOUSE ALE', 'Origen':...
# 2   {'Estilo': 'BELGIAN PALE ALE', 'Origen': 'Bélg...
# 3   {'Origen': 'Alemania', '% Alc. Exacto': '12', ...
# 4   {'Estilo': 'RAUCHBIER', 'Origen': 'Alemania', ...
# 5   {'Estilo': 'AMERICAN LAGER', 'Origen': 'EEUU',...
# 6   {'Estilo': 'DUBBEL', 'Origen': 'Bélgica', '% A...
# 7   {'Estilo': 'SIN ALCOHOL', 'Origen': 'Holanda',...
# 8   {'Estilo': 'DOPPELBOCK', 'Origen': 'Alemania',...
# 9   {'Estilo': 'TRIPEL', 'Origen': 'Bélgica', '% A...
# 10  {'Estilo': 'BELGIAN DARK STRONG ALE', 'Origen'...
# 11  {'Estilo': 'DUBBEL', 'Origen': 'Bélgica', '% A...
# 12  {'Estilo': 'RAUCHBIER', 'Origen': 'Alemania', ...
# 13  {'Estilo': 'KRIEK', 'Origen': 'Belgica', '% Al...
# 14  {'Estilo': 'TRIPEL', 'Origen': 'Bélgica', '% A...
# 15  {'Estilo': 'BELGIAN GOLDEN STRONG', 'Origen': ...
# 16  {'Estilo': 'RAUCHBIER', 'Origen': 'Alemania', ...
# 17  {'Estilo': 'IPA (INDIA PALE ALE)', 'Origen': '...
# 18  {'Estilo': 'PILSNER ', 'Origen': 'Cantabria', ...
# 19  {'Estilo': 'BELGIAN DARK STRONG ALE', 'Origen'...
# 20  {'Estilo': 'TRIPEL', 'Origen': 'Bélgica', '% A...
# 21  {'Estilo': 'BELGIAN DARK STRONG ALE', 'Origen'...
# 22  {'Origen': 'Bélgica', '% Alc. Exacto': '10.5',...
# 23  {'Estilo': 'IPA (INDIA PALE ALE)', 'Origen': '...
# 24  {'Estilo': 'BALTIC PORTER', 'Origen': 'Canadá'...
# 25  {'Estilo': 'BELGIAN DARK STRONG ALE', 'Origen'...
# 26  {'Estilo': 'QUADRUPEL / DARK STRONG ALE', 'Ori...
# 27  {'Estilo': 'TRIGO ALEMÁN (WEIZENDOPPELBOCK)', ...
# 28  {'Estilo': 'GUEUZE', 'Origen': 'Belgica', '% A...
# 29  {'Estilo': 'TRIGO BELGA (WITBIER)', 'Origen': ...
# 30  {'Estilo': 'BELGIAN DARK STRONG ALE', 'Origen'...
# 31  {'Estilo': 'SAISON / FARMHOUSE ALE', 'Origen':...
# 32  {'Estilo': 'SIN GLUTEN
# TRIPEL', 'Origen': 'Bél...
# 33  {'Estilo': 'QUADRUPEL / DARK STRONG ALE', 'Ori...
# 34  {'Estilo': 'ENGLISH BROWN ALE', 'Origen': 'Biz...
# 35  {'Estilo': 'APA (AMERICAN PALE ALE)', 'Origen'...
# 36  {'Estilo': 'KRIEK', '% Alc.': 'MEDIO (4-6%)', ...
# 37  {'Estilo': 'BELGIAN GOLDEN STRONG', 'Origen': ...
# 38  {'Estilo': 'SIN ALCOHOL', 'Origen': 'Dinamarca...
# 39  {'Estilo': 'DOPPELBOCK', 'Origen': 'Austria', ...
# 40  {'Estilo': 'QUADRUPEL / DARK STRONG ALE', 'Ori...
# 41  {'Estilo': 'WITBIER (TRIGO BELGA)', 'Origen': ...
# 42  {'Estilo': 'ENGLISH BROWN ALE', 'Origen': 'Ing...
# 43  {'Estilo': 'KELLERBIER', 'Origen': 'Alemania',...
# 44  {'Estilo': 'MAIBOCK', 'Origen': 'Alemania', '%...
# 45  {'Estilo': 'TRIPEL', 'Origen': 'Bélgica', '% A...
# 46  {'Estilo': 'DARK LAGER', 'Origen': 'República ...
# 47  {'Estilo': 'CALIFORNIA COMMON', 'Origen': 'EEU...
